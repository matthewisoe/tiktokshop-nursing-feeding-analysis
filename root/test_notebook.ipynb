# %%
# %run hegen_analysis.py
# Out:
# ...
#   LOADING DATA
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Desktop/Category Analysis Project/Hegen/Analysis/hegen_analysis.py:127
#     124 print("  LOADING DATA")
#     125 print("="*60)
# --> 127 shop_list    = pd.read_excel(f"{DATA_DIR}/Shop_list__Nursing___Feeding_.xlsx")
#     128 top_shops    = pd.read_excel(f"{DATA_DIR}/Top_selling_shops__Nursing___Feeding_.xlsx")
#     129 top_products = pd.read_excel(f"{DATA_DIR}/Top_selling_products__Nursing___Feeding_.xlsx")
#
# ...
